# %%
# %cd /content
# !rm -rf NOS
# !git clone https://mayankkashyap05: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@github.com/mayankkashyap05/uNOS.git
# %cd /content/uNOS

# %%
# !pip install -r requirements.txt

# %%
# !export PYTHONPATH=/content/NOS:$PYTHONPATH

# %%
# !rm -f models/nos_tokenizer_2k/model.safetensors
# !rm -f models/nos_tokenizer_base/model.safetensors
# !rm -f models/nos_base/model.safetensors
# !rm -f models/nos_small/model.safetensors
# !rm -f models/nos_mini/model.safetensors

# !wget -c -O models/nos_tokenizer_2k/model.safetensors \
https://huggingface.co/mayankkashyap2005/nos_tokenizer-2k/resolve/main/model.safetensors
# !wget -c -O models/nos_tokenizer_base/model.safetensors \
https://huggingface.co/mayankkashyap2005/nos_tokenizer-base/resolve/main/model.safetensors
# !wget -c -O models/nos_base/model.safetensors \
https://huggingface.co/mayankkashyap2005/nos_base/resolve/main/model.safetensors
# !wget -c -O models/nos_small/model.safetensors \
https://huggingface.co/mayankkashyap2005/nos_small/resolve/main/model.safetensors
# !wget -c -O models/nos_mini/model.safetensors \
https://huggingface.co/mayankkashyap2005/nos_mini/resolve/main/model.safetensors

# %%
# !ls -lh models/**/model.safetensors

# %%
import os

paths = [
    "models/nos_base/model.safetensors",
    "models/nos_small/model.safetensors",
    "models/nos_mini/model.safetensors",
    "models/nos_tokenizer_2k/model.safetensors",
    "models/nos_tokenizer_base/model.safetensors",
]

for p in paths:
    print(f"{p} ->", "✅ FOUND" if os.path.exists(p) else "❌ MISSING")

# %%
#!python train_sequential.py --config configs/solusdt_t4_config.yaml

#!python train_sequential.py --config configs/solusdt_a40_config.yaml

#!python train_sequential.py --config configs/solusdt_mx110_config.yaml

#!python train_sequential.py --config configs/test_15m_institutional_solusdt_t4_config.yaml

#!torchrun --nproc_per_node=1 train_sequential.py --config configs/solusdt_mx110_config.yaml

# Run HPO tuner
# !python hpo_tuner.py \
  --config configs/config_t40_hpo_fulltest.yaml \
  --phase both \
  --apply-best \
  --output-config configs/config_t40_hpo_winner.yaml

# Train using best config
#!python train_sequential.py \
 # --config configs/config_t40_hpo_winner.yaml

# %%
# !zip -r model.zip /content/uNOS/finetuned

# %%
from google.colab import files
files.download("model.zip")
